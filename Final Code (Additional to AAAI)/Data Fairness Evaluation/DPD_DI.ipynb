# %%
import pandas as pd

def compute_fairness_metrics(df, label_col, sensitive_col, privileged_value=1):
    privileged = df[df[sensitive_col] == privileged_value]
    unprivileged = df[df[sensitive_col] != privileged_value]

    p_priv = privileged[label_col].mean()
    p_unpriv = unprivileged[label_col].mean()

    dpd = abs(p_priv - p_unpriv)
    di = p_unpriv / p_priv if p_priv > 0 else float('inf')

    return dpd, di

# === Load datasets ===
real_data = pd.read_csv("compas_cleaned.csv")
synthetic_data = pd.read_csv("generated_data_Our_prompt_COMPAS.csv")

# === Column names
sensitive_attr = 'race_African-American'  # One-hot column
label_col = 'two_year_recid'  # Replace with your actual label column if different

# === Ensure numeric types
real_data[sensitive_attr] = pd.to_numeric(real_data[sensitive_attr], errors='coerce')
synthetic_data[sensitive_attr] = pd.to_numeric(synthetic_data[sensitive_attr], errors='coerce')
real_data[label_col] = pd.to_numeric(real_data[label_col], errors='coerce')
synthetic_data[label_col] = pd.to_numeric(synthetic_data[label_col], errors='coerce')

# === Compute fairness metrics
dpd_real, di_real = compute_fairness_metrics(real_data, label_col, sensitive_attr, privileged_value=1)
dpd_synth, di_synth = compute_fairness_metrics(synthetic_data, label_col, sensitive_attr, privileged_value=1)

# === Print results
print(f"📊 Fairness Metrics (Sensitive: {sensitive_attr}, Privileged: 1)")
print(f"Real Data     → DPD: {dpd_real:.4f}   DI: {di_real:.4f}")
print(f"Synthetic Data→ DPD: {dpd_synth:.4f}   DI: {di_synth:.4f}")
# Out:
# c:\Users\sshakibhamedan\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# c:\Users\sshakibhamedan\Anaconda3\lib\site-packages\pandas\core\arrays\masked.py:61: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.2' currently installed).
#   from pandas.core import (
# 📊 Fairness Metrics (Sensitive: race_African-American, Privileged: 1)
# Real Data     → DPD: 0.1323   DI: 0.7471
# Synthetic Data→ DPD: 0.0293   DI: 1.0578

# %%
import pandas as pd

def compute_fairness_metrics(df, label_col, sensitive_col, privileged_value=1):
    privileged = df[df[sensitive_col] == privileged_value]
    unprivileged = df[df[sensitive_col] != privileged_value]

    p_priv = privileged[label_col].mean()
    p_unpriv = unprivileged[label_col].mean()

    dpd = abs(p_priv - p_unpriv)
    di = p_unpriv / p_priv if p_priv > 0 else float('inf')

    return dpd, di

# === Load datasets ===
real_data = pd.read_csv("compas_cleaned.csv")
synthetic_data = pd.read_csv("generated_data_CLLM_prompt_COMPAS.csv")

# === Column names
sensitive_attr = 'race_African-American'  # One-hot column
label_col = 'two_year_recid'  # Replace with your actual label column if different

# === Ensure numeric types
real_data[sensitive_attr] = pd.to_numeric(real_data[sensitive_attr], errors='coerce')
synthetic_data[sensitive_attr] = pd.to_numeric(synthetic_data[sensitive_attr], errors='coerce')
real_data[label_col] = pd.to_numeric(real_data[label_col], errors='coerce')
synthetic_data[label_col] = pd.to_numeric(synthetic_data[label_col], errors='coerce')

# === Compute fairness metrics
dpd_real, di_real = compute_fairness_metrics(real_data, label_col, sensitive_attr, privileged_value=1)
dpd_synth, di_synth = compute_fairness_metrics(synthetic_data, label_col, sensitive_attr, privileged_value=1)

# === Print results
print(f"📊 Fairness Metrics (Sensitive: {sensitive_attr}, Privileged: 1)")
print(f"Real Data     → DPD: {dpd_real:.4f}   DI: {di_real:.4f}")
print(f"Synthetic Data→ DPD: {dpd_synth:.4f}   DI: {di_synth:.4f}")
# Out:
# 📊 Fairness Metrics (Sensitive: race_African-American, Privileged: 1)
# Real Data     → DPD: 0.1323   DI: 0.7471
# Synthetic Data→ DPD: 0.1243   DI: 0.7865

# %%
import pandas as pd

def compute_fairness_metrics(df, label_col, sensitive_col, privileged_value=1):
    privileged = df[df[sensitive_col] == privileged_value]
    unprivileged = df[df[sensitive_col] != privileged_value]

    p_priv = privileged[label_col].mean()
    p_unpriv = unprivileged[label_col].mean()

    dpd = abs(p_priv - p_unpriv)
    di = p_unpriv / p_priv if p_priv > 0 else float('inf')

    return dpd, di

# === Load datasets ===
real_data = pd.read_csv("compas_cleaned.csv")
synthetic_data = pd.read_csv("compas_synthetic_data_1000_200_epochs.csv")

# === Column names
sensitive_attr = 'race_African-American'  # One-hot column
label_col = 'two_year_recid'  # Replace with your actual label column if different

# === Ensure numeric types
real_data[sensitive_attr] = pd.to_numeric(real_data[sensitive_attr], errors='coerce')
synthetic_data[sensitive_attr] = pd.to_numeric(synthetic_data[sensitive_attr], errors='coerce')
real_data[label_col] = pd.to_numeric(real_data[label_col], errors='coerce')
synthetic_data[label_col] = pd.to_numeric(synthetic_data[label_col], errors='coerce')

# === Compute fairness metrics
dpd_real, di_real = compute_fairness_metrics(real_data, label_col, sensitive_attr, privileged_value=1)
dpd_synth, di_synth = compute_fairness_metrics(synthetic_data, label_col, sensitive_attr, privileged_value=1)

# === Print results
print(f"📊 Fairness Metrics (Sensitive: {sensitive_attr}, Privileged: 1)")
print(f"Real Data     → DPD: {dpd_real:.4f}   DI: {di_real:.4f}")
print(f"Synthetic Data→ DPD: {dpd_synth:.4f}   DI: {di_synth:.4f}")
# Out:
# 📊 Fairness Metrics (Sensitive: race_African-American, Privileged: 1)
# Real Data     → DPD: 0.1323   DI: 0.7471
# Synthetic Data→ DPD: 0.0246   DI: 1.0467

# %%
import pandas as pd

def compute_fairness_metrics(df, label_col, sensitive_col, privileged_value):
    privileged = df[df[sensitive_col] == privileged_value]
    unprivileged = df[df[sensitive_col] != privileged_value]

    p_priv = privileged[label_col].mean()
    p_unpriv = unprivileged[label_col].mean()

    dpd = abs(p_priv - p_unpriv)
    di = p_unpriv / p_priv if p_priv > 0 else float('inf')

    return dpd, di

# === Load datasets ===
real_data = pd.read_csv("bar_pass_prediction (processed version).csv")
synthetic_data = pd.read_csv("generated_data_Our_prompts_Law.csv")

# === Ensure numeric types ===
real_data['race'] = pd.to_numeric(real_data['race'], errors='coerce')
synthetic_data['race'] = pd.to_numeric(synthetic_data['race'], errors='coerce')
real_data['bar_passed'] = pd.to_numeric(real_data['bar_passed'], errors='coerce')
synthetic_data['bar_passed'] = pd.to_numeric(synthetic_data['bar_passed'], errors='coerce')

# === Set sensitive attribute and privileged group ===
sensitive_attr = 'race'
privileged_value = 7  # e.g., WHITE

# === Compute fairness metrics ===
dpd_real, di_real = compute_fairness_metrics(real_data, 'bar_passed', sensitive_attr, privileged_value)
dpd_synth, di_synth = compute_fairness_metrics(synthetic_data, 'bar_passed', sensitive_attr, privileged_value)

# === Print results ===
print("📊 Fairness Metrics Comparison (Sensitive attribute: race, Privileged: 7)")
print(f"Real Data     → DPD: {dpd_real:.4f}   DI: {di_real:.4f}")
print(f"Synthetic Data→ DPD: {dpd_synth:.4f}   DI: {di_synth:.4f}")
# Out:
# 📊 Fairness Metrics Comparison (Sensitive attribute: race, Privileged: 7)
# Real Data     → DPD: 0.1131   DI: 0.8830
# Synthetic Data→ DPD: 0.0178   DI: 1.0355

# %%
import pandas as pd

def compute_fairness_metrics(df, label_col, sensitive_col, privileged_value):
    privileged = df[df[sensitive_col] == privileged_value]
    unprivileged = df[df[sensitive_col] != privileged_value]

    p_priv = privileged[label_col].mean()
    p_unpriv = unprivileged[label_col].mean()

    dpd = abs(p_priv - p_unpriv)
    di = p_unpriv / p_priv if p_priv > 0 else float('inf')

    return dpd, di

# === Load datasets ===
real_data = pd.read_csv("bar_pass_prediction (processed version).csv")
synthetic_data = pd.read_csv("generated_data_CLLM_prompt_Law.csv")

# === Ensure numeric types ===
real_data['race'] = pd.to_numeric(real_data['race'], errors='coerce')
synthetic_data['race'] = pd.to_numeric(synthetic_data['race'], errors='coerce')
real_data['bar_passed'] = pd.to_numeric(real_data['bar_passed'], errors='coerce')
synthetic_data['bar_passed'] = pd.to_numeric(synthetic_data['bar_passed'], errors='coerce')

# === Set sensitive attribute and privileged group ===
sensitive_attr = 'race'
privileged_value = 7  # e.g., WHITE

# === Compute fairness metrics ===
dpd_real, di_real = compute_fairness_metrics(real_data, 'bar_passed', sensitive_attr, privileged_value)
dpd_synth, di_synth = compute_fairness_metrics(synthetic_data, 'bar_passed', sensitive_attr, privileged_value)

# === Print results ===
print("📊 Fairness Metrics Comparison (Sensitive attribute: race, Privileged: 7)")
print(f"Real Data     → DPD: {dpd_real:.4f}   DI: {di_real:.4f}")
print(f"Synthetic Data→ DPD: {dpd_synth:.4f}   DI: {di_synth:.4f}")
# Out:
# 📊 Fairness Metrics Comparison (Sensitive attribute: race, Privileged: 7)
# Real Data     → DPD: 0.1131   DI: 0.8830
# Synthetic Data→ DPD: 0.0138   DI: 1.0143

# %%
import pandas as pd

def compute_fairness_metrics(df, label_col, sensitive_col, privileged_value):
    privileged = df[df[sensitive_col] == privileged_value]
    unprivileged = df[df[sensitive_col] != privileged_value]

    p_priv = privileged[label_col].mean()
    p_unpriv = unprivileged[label_col].mean()

    dpd = abs(p_priv - p_unpriv)
    di = p_unpriv / p_priv if p_priv > 0 else float('inf')

    return dpd, di

# === Load datasets ===
real_data = pd.read_csv("bar_pass_prediction (processed version).csv")
synthetic_data = pd.read_csv("synthetic_law_data_decaf.csv")

# === Ensure numeric types ===
real_data['race'] = pd.to_numeric(real_data['race'], errors='coerce')
synthetic_data['race'] = pd.to_numeric(synthetic_data['race'], errors='coerce')
real_data['bar_passed'] = pd.to_numeric(real_data['bar_passed'], errors='coerce')
synthetic_data['bar_passed'] = pd.to_numeric(synthetic_data['bar_passed'], errors='coerce')

# === Set sensitive attribute and privileged group ===
sensitive_attr = 'race'
privileged_value = 7  # e.g., WHITE

# === Compute fairness metrics ===
dpd_real, di_real = compute_fairness_metrics(real_data, 'bar_passed', sensitive_attr, privileged_value)
dpd_synth, di_synth = compute_fairness_metrics(synthetic_data, 'bar_passed', sensitive_attr, privileged_value)

# === Print results ===
print("📊 Fairness Metrics Comparison (Sensitive attribute: race, Privileged: 7)")
print(f"Real Data     → DPD: {dpd_real:.4f}   DI: {di_real:.4f}")
print(f"Synthetic Data→ DPD: {dpd_synth:.4f}   DI: {di_synth:.4f}")
# Out:
# 📊 Fairness Metrics Comparison (Sensitive attribute: race, Privileged: 7)
# Real Data     → DPD: 0.1131   DI: 0.8830
# Synthetic Data→ DPD: 0.0138   DI: 1.0143

# %%
import pandas as pd

def compute_fairness_metrics(df, label_col, sensitive_col, privileged_value):
    privileged = df[df[sensitive_col] == privileged_value]
    unprivileged = df[df[sensitive_col] != privileged_value]

    p_priv = privileged[label_col].mean()
    p_unpriv = unprivileged[label_col].mean()

    dpd = abs(p_priv - p_unpriv)
    di = p_unpriv / p_priv if p_priv > 0 else float('inf')

    return dpd, di

# === Load datasets
real_data = pd.read_csv("Real_MIMIC.csv")
synthetic_data = pd.read_csv("generated_data_Our_prompts_MIMIC.csv")

# === Set parameters
sensitive_attr = "race"
privileged_value = "WHITE"
label_col = "los_seconds"

# === Preprocess labels
real_data[label_col] = pd.to_numeric(real_data[label_col], errors="coerce")
real_data = real_data.dropna(subset=[label_col])
real_data[label_col] = (real_data[label_col] >= 345600).astype(int)

synthetic_data[label_col] = pd.to_numeric(synthetic_data[label_col], errors="coerce")
synthetic_data = synthetic_data.dropna(subset=[label_col])
# no binarization needed for synthetic data

# === Ensure consistent type for sensitive attribute
real_data[sensitive_attr] = real_data[sensitive_attr].astype(str)
synthetic_data[sensitive_attr] = synthetic_data[sensitive_attr].astype(str)

# === Compute fairness metrics
dpd_real, di_real = compute_fairness_metrics(real_data, label_col, sensitive_attr, privileged_value)
dpd_synth, di_synth = compute_fairness_metrics(synthetic_data, label_col, sensitive_attr, privileged_value)

# === Output results
print(f"📊 Fairness Metrics Comparison (Sensitive: {sensitive_attr}, Privileged: {privileged_value})")
print(f"Real Data     → DPD: {dpd_real:.4f}   DI: {di_real:.4f}")
print(f"Synthetic Data→ DPD: {dpd_synth:.4f}   DI: {di_synth:.4f}")
# Out:
# 📊 Fairness Metrics Comparison (Sensitive: race, Privileged: WHITE)
# Real Data     → DPD: 0.0627   DI: 0.8368
# Synthetic Data→ DPD: 0.0039   DI: 0.9957

# %%
import pandas as pd

def compute_fairness_metrics(df, label_col, sensitive_col, privileged_value):
    privileged = df[df[sensitive_col] == privileged_value]
    unprivileged = df[df[sensitive_col] != privileged_value]

    p_priv = privileged[label_col].mean()
    p_unpriv = unprivileged[label_col].mean()

    dpd = abs(p_priv - p_unpriv)
    di = p_unpriv / p_priv if p_priv > 0 else float('inf')

    return dpd, di

# === Load datasets
real_data = pd.read_csv("Real_MIMIC.csv")
synthetic_data = pd.read_csv("generated_data_CLLM_prompt_Mimic.csv")

# === Set parameters
sensitive_attr = "race"
privileged_value = "WHITE"
label_col = "los_seconds"

# === Preprocess labels
real_data[label_col] = pd.to_numeric(real_data[label_col], errors="coerce")
real_data = real_data.dropna(subset=[label_col])
real_data[label_col] = (real_data[label_col] >= 345600).astype(int)

synthetic_data[label_col] = pd.to_numeric(synthetic_data[label_col], errors="coerce")
synthetic_data = synthetic_data.dropna(subset=[label_col])
# no binarization needed for synthetic data

# === Ensure consistent type for sensitive attribute
real_data[sensitive_attr] = real_data[sensitive_attr].astype(str)
synthetic_data[sensitive_attr] = synthetic_data[sensitive_attr].astype(str)

# === Compute fairness metrics
dpd_real, di_real = compute_fairness_metrics(real_data, label_col, sensitive_attr, privileged_value)
dpd_synth, di_synth = compute_fairness_metrics(synthetic_data, label_col, sensitive_attr, privileged_value)

# === Output results
print(f"📊 Fairness Metrics Comparison (Sensitive: {sensitive_attr}, Privileged: {privileged_value})")
print(f"Real Data     → DPD: {dpd_real:.4f}   DI: {di_real:.4f}")
print(f"Synthetic Data→ DPD: {dpd_synth:.4f}   DI: {di_synth:.4f}")
# Out:
# 📊 Fairness Metrics Comparison (Sensitive: race, Privileged: WHITE)
# Real Data     → DPD: 0.0627   DI: 0.8368
# Synthetic Data→ DPD: 0.0107   DI: 1.0176

# %%
import pandas as pd

def compute_fairness_metrics(df, label_col, sensitive_col, privileged_value):
    privileged = df[df[sensitive_col] == privileged_value]
    unprivileged = df[df[sensitive_col] != privileged_value]

    p_priv = privileged[label_col].mean()
    p_unpriv = unprivileged[label_col].mean()

    dpd = abs(p_priv - p_unpriv)
    di = p_unpriv / p_priv if p_priv > 0 else float('inf')

    return dpd, di

# === Load datasets
real_data = pd.read_csv("Real_MIMIC.csv")
synthetic_data = pd.read_csv("mimic_synthetic_data_1000_samples_DECAF.csv")

# === Set parameters
sensitive_attr = "race"
privileged_value = "WHITE"
label_col = "los_seconds"

# === Preprocess labels
real_data[label_col] = pd.to_numeric(real_data[label_col], errors="coerce")
real_data = real_data.dropna(subset=[label_col])
real_data[label_col] = (real_data[label_col] >= 345600).astype(int)

synthetic_data[label_col] = pd.to_numeric(synthetic_data[label_col], errors="coerce")
synthetic_data = synthetic_data.dropna(subset=[label_col])
# no binarization needed for synthetic data

# === Ensure consistent type for sensitive attribute
real_data[sensitive_attr] = real_data[sensitive_attr].astype(str)
synthetic_data[sensitive_attr] = synthetic_data[sensitive_attr].astype(str)

# === Compute fairness metrics
dpd_real, di_real = compute_fairness_metrics(real_data, label_col, sensitive_attr, privileged_value)
dpd_synth, di_synth = compute_fairness_metrics(synthetic_data, label_col, sensitive_attr, privileged_value)

# === Output results
print(f"📊 Fairness Metrics Comparison (Sensitive: {sensitive_attr}, Privileged: {privileged_value})")
print(f"Real Data     → DPD: {dpd_real:.4f}   DI: {di_real:.4f}")
print(f"Synthetic Data→ DPD: {dpd_synth:.4f}   DI: {di_synth:.4f}")
# Out:
# 📊 Fairness Metrics Comparison (Sensitive: race, Privileged: WHITE)
# Real Data     → DPD: 0.0627   DI: 0.8368
# Synthetic Data→ DPD: 5865.5062   DI: 0.9852
